# %% [markdown]
# ## To add in build_features.py

# %%
import pandas as pd

# %%
def build_features(df, categorical_columns, index_col=None, save_in=None):
    
    # Read DataFrame
    if isinstance(df, str):
        df_transformed = pd.read_csv(df)
    
    elif isinstance(df, pd.DataFrame):
        df_transformed = df.copy()
        
    else:
        ValueError("df should be a path file or a pandas DataFrame")
        
    # Set Index if not None
    if index_col is not None:
        df_transformed.set_index(index_col, inplace=True)
    
    if isinstance(categorical_columns, list):
        for cat_column in categorical_columns:
            df_dummies = pd.get_dummies(pd.Categorical(df_transformed[cat_column]), prefix=cat_column)
            df_dummies.set_index(df_transformed.index, inplace=True)
            df_transformed = pd.concat([df_transformed, df_dummies], axis=1)
        
        try:
            df_transformed = df_transformed.drop(categorical_columns, axis=1)
        except KeyError as k_exp:
            print("Warning:", k_exp)
            
        # Save dataframe in:
        if save_in is not None:
            df_transformed.reset_index().to_csv(save_in, index=False)
    
    else:
        ValueError("cat_columns should be a list")
    
    
    return df_transformed

# %% [markdown]
# ## To main.py

# %%
input_path_file = "/Users/lalachaimaenaciri/PycharmProjects/SCORE_LOW_HIGH_CAPSADSTR_INTENSITY/data/interim/clean_transcelerator_mar_2022.csv"
output_path_file = "/Users/lalachaimaenaciri/PycharmProjects/SCORE_LOW_HIGH_CAPSADSTR_INTENSITY/data/processed/clean_transcelerator_mar_2022.csv"

build_features_df = build_features(df=input_path_file,
               index_col="No",
               categorical_columns=['sex_f1_m2'],
               save_in=output_path_file)

# %%
build_features_df
# Out:
#      sour_low_taste_correct  astring_low_int  score_lowhigh_capsadstr1  \
# No
# 1                       1.0              3.0                      12.0
# 2                       0.0              2.0                       7.0
# 3                       1.0              3.0                      12.0
# 4                       0.0              2.0                       9.0
# 5                       1.0              1.0                      11.0
# ..                      ...              ...                       ...
# C51                     0.0              0.0                       7.0
# C6                      0.0              0.0                       7.0
# C7                      0.0              0.0                       6.0
# C8                      0.0              0.0                       7.0
# C9                      0.0              0.0                       9.0
#
#      astring_high_taste_correct  salty_low_int  sweet_high_taste_correct  \
# No
# 1                           1.0            4.0                       1.0
# 2                           1.0            3.0                       1.0
# 3                           1.0            5.0                       1.0
# 4                           1.0            4.0                       1.0
# 5                           1.0            4.0                       1.0
# ..                          ...            ...                       ...
# C51                         1.0            2.0                       1.0
# C6                          0.0            4.0                       1.0
# C7                          0.0            3.0                       1.0
# C8                          0.0            1.0                       1.0
# C9                          0.0            3.0                       1.0
#
#      bitter_high_taste_correct  sweet_low_int   Age        BMI  ...  \
# No                                                              ...
# 1                          1.0            5.0  31.0  20.202020  ...
# 2                          0.0            3.0  24.0  24.897060  ...
# 3                          1.0            3.0  25.0  24.618104  ...
# 4                          1.0            0.0  24.0  20.756387  ...
# 5                          1.0            1.0  23.0  24.212293  ...
# ..                         ...            ...   ...        ...  ...
# C51                        1.0            2.0  45.0  25.900000  ...
# C6                         1.0            2.0  38.0  35.294118  ...
# C7                         0.0            2.0  52.0  22.498174  ...
# C8                         1.0            0.0  33.0  19.267171  ...
# C9                         1.0            1.0  25.0  24.593211  ...
#
#      bitter_low_taste_correct  bitter_high_int  salty_high_int  \
# No
# 1                         1.0              4.0             4.0
# 2                         0.0              1.0             4.0
# 3                         1.0              5.0             5.0
# 4                         1.0              4.0             3.0
# 5                         1.0              4.0             3.0
# ..                        ...              ...             ...
# C51                       0.0              5.0             3.0
# C6                        0.0              1.0             5.0
# C7                        0.0              0.0             4.0
# C8                        1.0              2.0             2.0
# C9                        1.0              2.0             2.0
#
#      bitter_low_int  sour_low_int  depression  astring_low_taste_correct  \
# No
# 1               5.0           4.0        14.0                        1.0
# 2               3.0           3.0        16.0                        1.0
# 3               4.0           3.0        17.0                        1.0
# 4               3.0           0.0        18.0                        1.0
# 5               4.0           4.0        16.0                        1.0
# ..              ...           ...         ...                        ...
# C51             0.0           2.0        14.0                        0.0
# C6              0.0           0.0         5.0                        0.0
# C7              0.0           0.0        10.0                        0.0
# C8              1.0           0.0        14.0                        0.0
# C9              2.0           0.0         9.0                        0.0
#
#      salty_low_taste_correct  sex_f1_m2_1.0  sex_f1_m2_2.0
# No
# 1                        1.0              1              0
# 2                        1.0              0              1
# 3                        1.0              0              1
# 4                        1.0              0              1
# 5                        1.0              1              0
# ..                       ...            ...            ...
# C51                      0.0              0              1
# C6                       1.0              1              0
# C7                       1.0              0              1
# C8                       1.0              1              0
# C9                       1.0              0              1
#
# [153 rows x 33 columns]
